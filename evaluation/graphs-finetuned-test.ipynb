# %% [markdown]
# # Beat-This on Jazz Trio Database — Test Split Evaluation Report
#
# End-to-end analysis of the **beat_this** model on the JTD **test split** (**194 tracks**).
# Each track has been scored with the standard `mir_eval` beat-tracking metrics
# (F-measure, Cemgil, Goto, P-score, CMLc/t, AMLc/t, Information Gain) for both
# **beats** and **downbeats**.

# %%
import sys
sys.path.append('..')
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import seaborn as sns
from pathlib import Path

# Audio + model imports are optional: the heavy analysis cells below
# only need the CSV + .npz prediction files and should run even when
# soxr/torch/librosa are missing in the kernel.
try:
    import librosa
    import IPython.display as ipd
    AUDIO_OK = True
except Exception as e:
    print(f'[warn] audio stack unavailable ({e!r}); single-track playback cells will be skipped.')
    AUDIO_OK = False

try:
    from scripts.support_function import plot_beats
    from scripts.run_beat_this import run_beat_this
    MODEL_OK = True
except Exception as e:
    print(f'[warn] model stack unavailable ({e!r}); inference cells will be skipped.')
    MODEL_OK = False

sns.set_theme(style='whitegrid', context='talk')
plt.rcParams.update({
    'figure.figsize': (14, 6),
    'axes.titleweight': 'bold',
    'axes.titlesize': 14,
    'axes.labelsize': 12,
})

# %% [markdown]
# ## 1 — Load & enrich evaluation data

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
RESULTS_CSV = Path('csvs/beat_this_jtd_finetuned_test701515_enriched.csv')
if not RESULTS_CSV.exists():
    RESULTS_CSV = Path('csvs/beat_this_jtd_finetuned_test701515_enriched.csv')
PREDS_DIR  = Path('preds')

df = pd.read_csv(RESULTS_CSV)

# JTD track ids look like:
#   <leaderInstrument>-<song>-<sidemen>-<year>-<hash>
# e.g. 'barronk-allgodschildren-drummondrrileyb-1990-8b77c067'
parts = df['track_id'].str.split('-', expand=True)
df['leader'] = parts[0]
year_col = parts.iloc[:, -2]
df['year'] = pd.to_numeric(year_col, errors='coerce').astype('Int64')
df['decade'] = (df['year'] // 10 * 10).astype('Int64')

# Ensure time_signature is present
if 'time_signature' not in df.columns:
    df['time_signature'] = 4  # Default to 4 if unknown

# Track length in beats and approx. seconds (using inferred mean tempo of 120 BPM as floor;
# we'll get a sharper estimate from the .npz files later).
df['beat_count_diff'] = df['n_pred_beats'] - df['n_gt_beats']
df['downbeat_count_diff'] = df['n_pred_downbeats'] - df['n_gt_downbeats']
df['beat_count_ratio'] = df['n_pred_beats'] / df['n_gt_beats']
df['downbeat_count_ratio'] = df['n_pred_downbeats'] / df['n_gt_downbeats']

print(f'Loaded {len(df):,} tracks   |   {df["leader"].nunique()} unique leaders   |   '
      f'years {int(df["year"].min())}–{int(df["year"].max())}')
print(f'Status breakdown: {df["status"].value_counts().to_dict()}')
df.head(5)
# Out:
# Loaded 194 tracks   |   27 unique leaders   |   years 1949–2010
# Status breakdown: {'ok': 194}
#                                             track_id  \
# 0  barronk-bouncinwithbud-carterrcobhamb-2003-543...
# 1  barronk-outofnowhere-carterrcobhamb-2003-5ef86b93
# 2  barronk-surreywiththefringeon-drummondrrileyb-...
# 3   barronk-theonlyone-drummondrrileyb-1996-2d0f261a
# 4  barronk-thereisnogreaterlove-williamsbrileyb-1...
#
#                                           audio_path  n_gt_beats  \
# 0  /home/rht9410/jtd_data/barronk-bouncinwithbud-...         761
# 1  /home/rht9410/jtd_data/barronk-outofnowhere-ca...         377
# 2  /home/rht9410/jtd_data/barronk-surreywiththefr...         568
# 3  /home/rht9410/jtd_data/barronk-theonlyone-drum...        1019
# 4  /home/rht9410/jtd_data/barronk-thereisnogreate...         882
#
#    n_pred_beats  n_gt_downbeats  n_pred_downbeats  infer_seconds status  \
# 0           765             190               432          1.923     ok
# 1           379              94                99          0.296     ok
# 2           570             142               511          0.291     ok
# 3          1018             255               279          0.701     ok
# 4           887             221               393          0.553     ok
#
#    beat_F-measure  beat_Cemgil  ...    bandleader  year       tempo  \
# 0        0.983210     0.940740  ...  Kenny Barron  2003  220.121452
# 1        0.977839     0.926418  ...  Kenny Barron  2003  195.171873
# 2        0.998172     0.970409  ...  Kenny Barron  1990  267.091451
# 3        0.989526     0.960947  ...  Kenny Barron  1996  202.618901
# 4        0.872622     0.799591  ...  Kenny Barron  1984  210.550595
#
#    excerpt_duration   leader  decade  beat_count_diff  downbeat_count_diff  \
# 0             03:28  barronk    2000                4                  242
# 1             01:56  barronk    2000                2                    5
# 2             02:08  barronk    1990                2                  369
# 3             05:02  barronk    1990               -1                   24
# 4             04:12  barronk    1980                5                  172
#
#    beat_count_ratio  downbeat_count_ratio
# 0          1.005256              2.273684
# 1          1.005305              1.053191
# 2          1.003521              3.598592
# 3          0.999019              1.094118
# 4          1.005669              1.778281
#
# [5 rows x 37 columns]

# %% [markdown]
# ## 2 — Headline performance numbers
#
# Across all 1,294 tracks, summarise every metric with mean / median / std and
# the share of tracks crossing the usual quality bands (>0.9 = excellent,
# >0.7 = good, >0.5 = fair, ≤0.5 = poor).
#
# ### Metric definitions
#
# All metrics come from `mir_eval.beat`. They are applied twice — once to the
# list of beat times and once to the list of downbeat times — yielding the
# `beat_*` and `downbeat_*` columns. Unless noted, scores are in **[0, 1]**
# and higher is better.
#
# | Metric | What it measures | Tolerance / detail |
# |---|---|---|
# | **F-measure** | Harmonic mean of precision and recall over predicted vs. reference events. | A prediction counts as correct if it falls within **±70 ms** of a reference event. |
# | **Cemgil** | Sum of Gaussians centred on each reference event, evaluated at each prediction; normalised by `max(N_pred, N_ref)`. | Gaussian σ = **40 ms** — softer than F-measure: small timing errors are penalised proportionally rather than discretely. |
# | **Goto** | Binary {0, 1} indicator of whether the system tracked the beat "well" overall. | Returns 1 only if the longest correctly-tracked segment covers **≥ 25 %** of the track *and* the inter-beat intervals are stable. Tolerates one large error; otherwise 0. |
# | **P-score** | Normalised cross-correlation of impulse trains representing reference and predicted beats. | Tolerance window is **20 % of the median reference IBI** (so it adapts to tempo). |
# | **CMLc** | *Correct Metrical Level — continuous.* The **longest contiguous** stretch tracked at the same metrical level as the reference, divided by track length. | Strict: predictions must match the reference tempo and phase. |
# | **CMLt** | *Correct Metrical Level — total.* The **total** time correctly tracked at the same metrical level (not necessarily contiguous). | Same strictness as CMLc, but rewards intermittent recovery. |
# | **AMLc** | *Allowed Metrical Levels — continuous.* Like CMLc, but **octave errors are allowed** (half-tempo, double-tempo, off-beat by half a beat). | Useful for separating "wrong tempo" from "wrong phase" failures. |
# | **AMLt** | *Allowed Metrical Levels — total.* Like CMLt with the same octave-error allowance. | Highest of the four CML/AML scores by construction. |
# | **Information gain** | Information-theoretic measure: mutual information between the histogram of beat errors and a uniform distribution. | Reported in **bits**; range is `[0, log₂(num_bins)] ≈ [0, 5.3]`. Higher = errors are tightly concentrated near zero. |
#
# > **Note on the NaN columns.** `beat_CMLc/CMLt/AMLc/AMLt` and their downbeat
# > counterparts are all empty in this CSV — the evaluation script we ran did
# > not request those continuity scores. They are listed above for completeness
# > and will be filtered out of the correlation heatmap automatically.
#
# > **Beat vs. downbeat metrics.** The two families use the *same definitions*
# > applied to different event lists. Beats = every pulse; downbeats = the "1"
# > of each bar only. Downbeat scores are therefore much more sensitive to
# > **phase / metre** errors: a tracker can hit every beat perfectly yet still
# > score 0 on `downbeat_F-measure` if it locks onto beat 2 instead of beat 1.

# %%
metric_cols = [c for c in df.columns if c.startswith('beat_') or c.startswith('downbeat_')]
metric_cols = [c for c in metric_cols if c not in ('beat_count_diff','beat_count_ratio',
                                                    'downbeat_count_diff','downbeat_count_ratio')]

summary = df[metric_cols].agg(['mean','median','std','min','max']).T
summary['n_valid'] = df[metric_cols].notna().sum().values
summary = summary.round(3)
summary
# Out:
#                             mean  median    std    min    max  n_valid
# beat_F-measure             0.975   0.999  0.064  0.531  1.000      194
# beat_Cemgil                0.929   0.954  0.073  0.489  0.982      194
# beat_Goto                  0.948   1.000  0.222  0.000  1.000      194
# beat_P-score               0.969   0.998  0.080  0.484  1.000      194
# beat_CMLc                  0.806   0.993  0.278  0.000  1.000      194
# beat_CMLt                  0.951   0.996  0.141  0.000  1.000      194
# beat_AMLc                  0.816   0.995  0.266  0.036  1.000      194
# beat_AMLt                  0.962   0.997  0.103  0.126  1.000      194
# beat_Information gain      0.554   0.569  0.094  0.095  0.693      194
# downbeat_F-measure         0.600   0.571  0.234  0.000  1.000      194
# downbeat_Cemgil            0.573   0.537  0.229  0.000  0.975      194
# downbeat_Goto              0.124   0.000  0.330  0.000  1.000      194
# downbeat_P-score           0.496   0.415  0.251  0.000  1.000      194
# downbeat_CMLc              0.162   0.024  0.264  0.000  1.000      194
# downbeat_CMLt              0.243   0.046  0.326  0.000  1.000      194
# downbeat_AMLc              0.199   0.059  0.277  0.000  1.000      194
# downbeat_AMLt              0.328   0.224  0.322  0.000  1.000      194
# downbeat_Information gain  0.556   0.524  0.165  0.094  0.931      194

# %%
def bands(series):
    s = series.dropna()
    return pd.Series({
        'Excellent (>0.9)': (s > 0.9).mean(),
        'Good (0.7-0.9]':   ((s > 0.7) & (s <= 0.9)).mean(),
        'Fair (0.5-0.7]':   ((s > 0.5) & (s <= 0.7)).mean(),
        'Poor (≤0.5)':      (s <= 0.5).mean(),
    })

band_df = pd.DataFrame({
    'Beats':     bands(df['beat_F-measure']),
    'Downbeats': bands(df['downbeat_F-measure']),
})

colors = ['#27ae60', '#f1c40f', '#e67e22', '#c0392b']
ax = (band_df * 100).T.plot(kind='barh', stacked=True, figsize=(14, 4.5),
                            color=colors, width=0.6, edgecolor='white', linewidth=1)

ax.xaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_xlim(0, 100)
ax.set_xlabel('Percentage of Tracks', fontsize=12, fontweight='bold', alpha=0.7)
ax.set_title('Quality Band Distribution: Beats vs Downbeats', fontsize=16, pad=20)
ax.legend(loc='lower center', bbox_to_anchor=(0.5, -0.6), ncol=4, frameon=False, fontsize=11)

for c in ax.containers:
    labels = [f'{v.get_width():.1f}%' if v.get_width() > 3 else '' for v in c]
    ax.bar_label(c, labels=labels, label_type='center', color='white', fontsize=10, fontweight='bold')

sns.despine(left=True, bottom=True)
plt.tight_layout()
plt.show()

(band_df * 100).round(1).astype(str) + '%'
# Out:
#                   Beats Downbeats
# Excellent (>0.9)  94.8%     14.4%
# Good (0.7-0.9]     3.1%     23.2%
# Fair (0.5-0.7]     2.1%     21.1%
# Poor (≤0.5)        0.0%     41.2%

# %% [markdown]
# ## 4 — Performance by Metre
#
# Analyze how the model performs across different time signatures (metres). This helps identify if the model has a bias towards 4/4 time or struggles with 3/4 (waltz) feels.

# %%
# Frequency breakdown of all metres in the dataset
meter_counts = df['time_signature'].value_counts().sort_index()
print(f"Total Tracks analyzed: {len(df):,}")
print("Breakdown of Metres in JTD Dataset:")
for meter, count in meter_counts.items():
    print(f"- {meter}/4: {count} tracks")
# Out:
# Total Tracks analyzed: 194
# Breakdown of Metres in JTD Dataset:
# - 3/4: 9 tracks
# - 4/4: 185 tracks

# %%
# Group by metre and calculate average performance
metre_stats = df.groupby('time_signature')[['beat_F-measure', 'downbeat_F-measure']].agg(['mean', 'median', 'std', 'count'])

# Display stats with premium formatting
print("Performance Statistics by Metre:")
display(metre_stats.style.format("{:.3f}").background_gradient(cmap='Blues'))

# Visualization - Premium UI
fig, axes = plt.subplots(1, 2, figsize=(16, 7), sharey=True)

# Beat F-measure by metre
sns.boxplot(x='time_signature', y='beat_F-measure', data=df, ax=axes[0], 
            palette='viridis', width=0.6, showfliers=False, linewidth=1.5)
sns.stripplot(x='time_signature', y='beat_F-measure', data=df, ax=axes[0], 
              color='black', alpha=0.1, size=2, jitter=0.2)
axes[0].set_title('Beat Tracking Performance', fontsize=15, fontweight='bold', pad=15)
axes[0].set_xlabel('Metre (Beats per Bar)', fontsize=12)
axes[0].set_ylabel('F-measure', fontsize=12)

# Downbeat F-measure by metre
sns.boxplot(x='time_signature', y='downbeat_F-measure', data=df, ax=axes[1], 
            palette='magma', width=0.6, showfliers=False, linewidth=1.5)
sns.stripplot(x='time_signature', y='downbeat_F-measure', data=df, ax=axes[1], 
              color='black', alpha=0.1, size=2, jitter=0.2)
axes[1].set_title('Downbeat Tracking Performance', fontsize=15, fontweight='bold', pad=15)
axes[1].set_xlabel('Metre (Beats per Bar)', fontsize=12)

plt.suptitle('Model Performance Sensitivity to Metrical Structure', fontsize=18, fontweight='bold', y=1.05)
plt.tight_layout()
sns.despine(trim=True)
plt.show()
# Out:
# Performance Statistics by Metre:
# <style type="text/css">
# #T_0e70b_row0_col0, #T_0e70b_row0_col1, #T_0e70b_row0_col4, #T_0e70b_row0_col5, #T_0e70b_row1_col2, #T_0e70b_row1_col3, #T_0e70b_row1_col6, #T_0e70b_row1_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_0e70b_row0_col2, #T_0e70b_row0_col3, #T_0e70b_row0_col6, #T_0e70b_row0_col7, #T_0e70b_row1_col0, #T_0e70b_row1_col1, #T_0e70b_row1_col4, #T_0e70b_row1_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_0e70b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e70b_level0_col0" class="col_heading level0 col0" colspan="4">beat_F-measure</th>
#       <th id="T_0e70b_level0_col4" class="col_heading level0 col4" colspan="4">downbeat_F-measure</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_0e70b_level1_col0" class="col_heading level1 col0" >mean</th>
#       <th id="T_0e70b_level1_col1" class="col_heading level1 col1" >median</th>
#       <th id="T_0e70b_level1_col2" class="col_heading level1 col2" >std</th>
#       <th id="T_0e70b_level1_col3" class="col_heading level1 col3" >count</th>
#       <th id="T_0e70b_level1_col4" class="col_heading level1 col4" >mean</th>
#       <th id="T_0e70b_level1_col5" class="col_heading level1 col5" >median</th>
#       <th id="T_0e70b_level1_col6" class="col_heading level1 col6" >std</th>
#       <th id="T_0e70b_level1_col7" class="col_heading level1 col7" >count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >time_signature</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e70b_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_0e70b_row0_col0" class="data row0 col0" >0.993</td>
#       <td id="T_0e70b_row0_col1" class="data row0 col1" >1.000</td>
#       <td id="T_0e70b_row0_col2" class="data row0 col2" >0.016</td>
#       <td id="T_0e70b_row0_col3" class="data row0 col3" >9.000</td>
#       <td id="T_0e70b_row0_col4" class="data row0 col4" >0.649</td>
#       <td id="T_0e70b_row0_col5" class="data row0 col5" >0.615</td>
#       <td id="T_0e70b_row0_col6" class="data row0 col6" >0.153</td>
#       <td id="T_0e70b_row0_col7" class="data row0 col7" >9.000</td>
#     </tr>
#     <tr>
#       <th id="T_0e70b_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_0e70b_row1_col0" class="data row1 col0" >0.974</td>
#       <td id="T_0e70b_row1_col1" class="data row1 col1" >0.999</td>
#       <td id="T_0e70b_row1_col2" class="data row1 col2" >0.066</td>
#       <td id="T_0e70b_row1_col3" class="data row1 col3" >185.000</td>
#       <td id="T_0e70b_row1_col4" class="data row1 col4" >0.597</td>
#       <td id="T_0e70b_row1_col5" class="data row1 col5" >0.544</td>
#       <td id="T_0e70b_row1_col6" class="data row1 col6" >0.237</td>
#       <td id="T_0e70b_row1_col7" class="data row1 col7" >185.000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Beat and Downbeat Errors by Metre
#
# Direct comparison of the tracking error (1 - F-measure) for both beats and downbeats across different metres.

# %%
# Calculate errors
df['beat_error'] = 1 - df['beat_F-measure']
df['downbeat_error'] = 1 - df['downbeat_F-measure']

# Group by metre and calculate mean errors
error_stats = df.groupby('time_signature')[['beat_error', 'downbeat_error']].mean() * 100

# Visualization of errors - Premium UI
fig, ax = plt.subplots(figsize=(12, 7))

error_stats.plot(kind='bar', ax=ax, color=['#3498db', '#e74c3c'], width=0.6, edgecolor='white', linewidth=1)
ax.set_title('Mean Tracking Errors by Metre', fontsize=16, fontweight='bold', pad=20)
ax.set_xlabel('Metre (Beats per Bar)', fontsize=13, fontweight='bold')
ax.set_ylabel('Mean Error (1 - F-measure)', fontsize=13, fontweight='bold')
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.legend(['Beat Error', 'Downbeat Error'], frameon=False, fontsize=12)

# Add value labels
for p in ax.patches:
    ax.annotate(f'{p.get_height():.1f}%', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', 
                xytext=(0, 9), 
                textcoords='offset points',
                fontsize=11, fontweight='bold', alpha=0.8)

plt.xticks(rotation=0)
sns.despine()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3 — Score distributions
#
# Histogram + ECDF for the two headline F-measures. Vertical lines show the
# median (solid) and the 25/75th percentiles (dashed) so you can read off
# the bulk of the distribution at a glance.

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 10))
pairs = [('beat_F-measure','#3498db','Beats'),
         ('downbeat_F-measure','#e74c3c','Downbeats')]

for col_idx, (metric, color, label) in enumerate(pairs):
    series = df[metric].dropna()
    ax_h, ax_e = axes[0, col_idx], axes[1, col_idx]

    sns.histplot(series, bins=40, kde=True, color=color, ax=ax_h, edgecolor='white')
    q1, med, q3 = series.quantile([0.25, 0.5, 0.75])
    for q, ls, lbl in [(q1,'--','25%'),(med,'-','median'),(q3,'--','75%')]:
        ax_h.axvline(q, color='black', ls=ls, lw=1.2, alpha=0.7)
        ax_h.text(q, ax_h.get_ylim()[1]*0.95, f'{lbl}\n{q:.2f}', ha='center',
                  fontsize=9, va='top', bbox=dict(facecolor='white', alpha=0.6, edgecolor='none'))
    ax_h.set_xlim(0, 1)
    ax_h.set_title(f'{label}: F-measure histogram (mean={series.mean():.3f})')
    ax_h.set_xlabel('F-measure')

    sns.ecdfplot(series, color=color, lw=2.5, ax=ax_e)
    ax_e.set_xlim(0, 1); ax_e.set_ylim(0, 1)
    ax_e.axhline(0.5, color='gray', ls=':', lw=1)
    ax_e.set_title(f'{label}: cumulative distribution')
    ax_e.set_xlabel('F-measure'); ax_e.set_ylabel('P(score ≤ x)')

plt.tight_layout(); plt.show()

# %% [markdown]
# ## 4 — All metrics side-by-side
#
# Boxplots with raw points overlayed (a *strip* plot). Useful for spotting
# metrics whose tails are very different from the median — e.g. Goto is
# binary-ish so its box collapses, while Information Gain has a much wider
# spread than F-measure.

# %%
plot_cols = [
    'beat_F-measure','beat_Cemgil','beat_P-score','beat_Information gain',
    'downbeat_F-measure','downbeat_Cemgil','downbeat_P-score','downbeat_Information gain',
]
melted = df[plot_cols].melt(var_name='metric', value_name='score').dropna()
melted['domain'] = melted['metric'].str.split('_').str[0]

plt.figure(figsize=(16, 7))
ax = sns.boxplot(x='metric', y='score', data=melted, hue='domain',
                 palette={'beat':'#3498db','downbeat':'#e74c3c'},
                 width=0.6, fliersize=0, dodge=False)
sns.stripplot(x='metric', y='score', data=melted.sample(n=min(2000, len(melted)), random_state=0),
              color='black', alpha=0.12, size=2, ax=ax)
for i, m in enumerate(plot_cols):
    mu = df[m].mean()
    ax.scatter(i, mu, marker='D', color='white', edgecolor='black', s=60, zorder=5)
    ax.text(i, mu + 0.03, f'{mu:.2f}', ha='center', fontsize=9, fontweight='bold')
ax.set_title('Per-metric score distribution (white diamond = mean)')
ax.set_xticklabels([t.get_text().replace('_','\n') for t in ax.get_xticklabels()], rotation=0)
ax.set_ylim(-0.02, 1.05)
ax.set_xlabel(''); ax.legend(title='', loc='lower right')
plt.tight_layout(); plt.show()

# %% [markdown]
# ## 5 — How do the metrics co-vary?
#
# Pearson correlation across every numeric metric. Tight clusters reveal
# metrics that essentially measure the same thing (e.g. beat-F vs beat-Cemgil),
# while a low cross-block correlation tells us downbeat tracking is a
# **genuinely separate failure mode** from beat tracking.

# %%
corr_cols = [c for c in metric_cols if df[c].notna().sum() > 100]
corr = df[corr_cols].corr()

pretty_labels = [c.replace('_', ' ').title() for c in corr.columns]

fig, ax = plt.subplots(figsize=(14, 11))
sns.heatmap(
    corr,
    cmap='RdBu_r',
    center=0,
    vmin=-1,
    vmax=1,
    annot=True,
    fmt='.2f',
    annot_kws={'size': 8},
    linewidths=0.5,
    linecolor='white',
    square=True,
    cbar_kws={'shrink': 0.75, 'label': 'Pearson r'},
    ax=ax,
    xticklabels=pretty_labels,
    yticklabels=pretty_labels,
)
ax.set_title('Correlation Between Evaluation Metrics', fontsize=16, pad=18)
ax.tick_params(axis='both', labelsize=9)
plt.setp(ax.get_xticklabels(), rotation=45, ha='right', rotation_mode='anchor')
plt.setp(ax.get_yticklabels(), rotation=0)
plt.tight_layout()
plt.show()

# %%
# Joint plot: beat F vs downbeat F with marginal distributions, colored by data density.
g = sns.JointGrid(data=df, x='beat_F-measure', y='downbeat_F-measure',
                  height=8, ratio=4, space=0.05)
g.plot_joint(sns.histplot, bins=40, pmax=0.9, cmap='viridis', cbar=False)
g.plot_marginals(sns.histplot, bins=40, color='#7f8c8d', element='step')
g.ax_joint.plot([0,1],[0,1], color='red', ls='--', lw=1.2, label='y = x')

# Highlight failure quadrants.
good_b_bad_db = ((df['beat_F-measure'] > 0.8) & (df['downbeat_F-measure'] < 0.2)).sum()
both_bad     = ((df['beat_F-measure'] < 0.5) & (df['downbeat_F-measure'] < 0.5)).sum()
g.ax_joint.text(0.95, 0.10, f'good beats / failed downbeats:\n{good_b_bad_db} tracks',
                ha='right', fontsize=10,
                bbox=dict(facecolor='white', alpha=0.85, edgecolor='black'))
g.ax_joint.text(0.05, 0.05, f'both failed:\n{both_bad} tracks', ha='left', fontsize=10,
                bbox=dict(facecolor='white', alpha=0.85, edgecolor='black'))
g.ax_joint.set_xlim(0,1); g.ax_joint.set_ylim(0,1)
g.ax_joint.legend(loc='upper left')
g.figure.suptitle('Beat F-measure vs. Downbeat F-measure', y=1.02)
plt.show()

rho = df[['beat_F-measure','downbeat_F-measure']].corr().iloc[0,1]
print(f'Pearson r(beat_F, downbeat_F) = {rho:.3f}')
# Out:
# Pearson r(beat_F, downbeat_F) = 0.280

# %% [markdown]
# ## 6 — Beat & downbeat count accuracy
#
# Beat-this returns a list of timestamps; the simplest sanity check is
# whether it returns roughly the right *number* of events. A ratio far
# from 1.0 is a smoking gun for half/double-time errors (≈0.5 or ≈2.0).

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
for ax, kind, color in zip(axes, ['beat','downbeat'], ['#3498db','#e74c3c']):
    ratio = df[f'{kind}_count_ratio'].dropna()
    sns.histplot(ratio.clip(0, 3), bins=60, color=color, ax=ax, edgecolor='white')
    ax.axvline(1.0, color='black', ls='-', lw=1.5, label='1.0 (perfect)')
    ax.axvline(0.5, color='gray',  ls='--', lw=1.2, label='0.5 (half-time)')
    ax.axvline(2.0, color='gray',  ls=':',  lw=1.2, label='2.0 (double-time)')
    ax.set_title(f'{kind.capitalize()} count ratio  (n_pred / n_gt)')
    ax.set_xlabel('ratio'); ax.set_xlim(0, 3); ax.legend(fontsize=10)
    near_perfect = ((ratio > 0.95) & (ratio < 1.05)).mean() * 100
    ax.text(0.02, 0.95, f'{near_perfect:.1f}% within ±5%', transform=ax.transAxes,
            va='top', fontsize=11, bbox=dict(facecolor='white', alpha=0.85))
plt.tight_layout(); plt.show()

# %% [markdown]
# ## 7 — Inference speed
#
# How long the model spent per track. The first run usually pays a JIT/warm-up
# cost — easy to spot as an outlier here.

# %%
infer = df['infer_seconds'].dropna()
fig, axes = plt.subplots(1, 2, figsize=(16, 5))

sns.histplot(infer.clip(upper=5), bins=60, color='#9b59b6', ax=axes[0], edgecolor='white')
axes[0].axvline(infer.median(), color='black', ls='-',  lw=1.5, label=f'median {infer.median():.2f}s')
axes[0].axvline(infer.mean(),   color='black', ls='--', lw=1.5, label=f'mean   {infer.mean():.2f}s')
axes[0].set_title('Inference time per track (clipped at 5 s)')
axes[0].set_xlabel('seconds'); axes[0].legend()

axes[1].scatter(df['n_gt_beats'], df['infer_seconds'], alpha=0.3, s=15, color='#9b59b6')
axes[1].set_yscale('log')
axes[1].set_xlabel('# ground-truth beats (proxy for length)')
axes[1].set_ylabel('inference time (s, log)')
axes[1].set_title('Inference time vs. track length')
plt.tight_layout(); plt.show()

print(f'Inference time: median={infer.median():.3f}s   mean={infer.mean():.3f}s   '
      f'p95={infer.quantile(0.95):.2f}s   max={infer.max():.2f}s')
print('Top 5 slowest tracks (likely warm-up + long files):')
df.nlargest(5, 'infer_seconds')[['track_id','n_gt_beats','infer_seconds']]
# Out:
# Inference time: median=0.265s   mean=0.311s   p95=0.68s   max=1.92s
# Top 5 slowest tracks (likely warm-up + long files):
#                                               track_id  n_gt_beats  \
# 0    barronk-bouncinwithbud-carterrcobhamb-2003-543...         761
# 78   hawesh-bluehampbluebird-mcbeechaynesr-1973-c54...         829
# 5    barronk-wellyouneednt-drummondrrileyb-1996-fbe...        1775
# 106  jarrettk-butchbutch-peacockgdejohnettej-1993-f...        1195
# 167  powellb-reetsandi-hultcrantztspangbergs-1962-c...        1404
#
#      infer_seconds
# 0            1.923
# 78           1.092
# 5            0.933
# 106          0.873
# 167          0.849

# %% [markdown]
# ## 8 — Performance by band leader
#
# JTD is built around a few canonical pianists. Some leaders may be
# systematically harder — often the ones who play very rubato or out of
# tempo (Jarrett, Evans solo intros).

# %%
leader_stats = (df.groupby('leader')
                  .agg(n=('track_id','count'),
                       beat_F=('beat_F-measure','mean'),
                       downbeat_F=('downbeat_F-measure','mean'))
                  .sort_values('downbeat_F'))
leader_stats = leader_stats[leader_stats['n'] >= 5]

fig, ax = plt.subplots(figsize=(13, max(4, 0.32 * len(leader_stats))))
y = np.arange(len(leader_stats))
ax.barh(y - 0.2, leader_stats['beat_F'],     height=0.4, color='#3498db', label='beat F')
ax.barh(y + 0.2, leader_stats['downbeat_F'], height=0.4, color='#e74c3c', label='downbeat F')
ax.set_yticks(y); ax.set_yticklabels([f'{l} (n={n})' for l, n in zip(leader_stats.index, leader_stats['n'])])
ax.set_xlim(0, 1); ax.axvline(df['beat_F-measure'].mean(),     color='#3498db', ls=':', lw=1)
ax.axvline(df['downbeat_F-measure'].mean(), color='#e74c3c', ls=':', lw=1)
ax.set_xlabel('mean F-measure'); ax.set_title('Mean F-measure by band leader (n ≥ 5 tracks)')
ax.legend(loc='lower right'); ax.invert_yaxis()
plt.tight_layout(); plt.show()

leader_stats.round(3)
# Out:
#             n  beat_F  downbeat_F
# leader
# jarrettk   12   0.944       0.414
# kellyw      5   0.975       0.481
# waltonc     5   0.998       0.484
# tynerm     10   0.947       0.490
# mancej      6   0.986       0.512
# coreac      5   0.957       0.524
# evansb     37   0.982       0.551
# monkt       5   0.907       0.558
# jamala     12   0.963       0.573
# barronk     6   0.970       0.605
# petersono  15   0.981       0.607
# timmonsb    6   0.998       0.676
# flanagant   8   0.990       0.693
# jonesh      7   0.989       0.730
# powellb    11   0.996       0.765
# nicholsh    8   1.000       0.770
# brownr      9   0.936       0.781

# %% [markdown]
# ## 9 — Performance across recording eras
#
# Older recordings often have noisier audio, more variable mic placement, and
# drummers using brushes — all of which can stress beat trackers.

# %%
decade_stats = (df.dropna(subset=['decade'])
                  .groupby('decade')
                  .agg(n=('track_id','count'),
                       beat_F=('beat_F-measure','mean'),
                       downbeat_F=('downbeat_F-measure','mean'),
                       beat_F_std=('beat_F-measure','std'),
                       downbeat_F_std=('downbeat_F-measure','std')))

fig, ax = plt.subplots(figsize=(13, 6))
x = decade_stats.index.astype(int)
ax.errorbar(x, decade_stats['beat_F'],     yerr=decade_stats['beat_F_std'],
            fmt='o-', color='#3498db', label='beat F', capsize=4, lw=2)
ax.errorbar(x, decade_stats['downbeat_F'], yerr=decade_stats['downbeat_F_std'],
            fmt='s-', color='#e74c3c', label='downbeat F', capsize=4, lw=2)
for xi, n in zip(x, decade_stats['n']):
    ax.text(xi, 0.02, f'n={n}', ha='center', fontsize=9, color='gray')
ax.set_ylim(0, 1.05); ax.set_xlabel('Decade'); ax.set_ylabel('Mean F-measure (±1σ)')
ax.set_title('Performance by recording decade')
ax.legend(); plt.tight_layout(); plt.show()

decade_stats.round(3)
# Out:
#          n  beat_F  downbeat_F  beat_F_std  downbeat_F_std
# decade
# 1940     1   0.667       0.650         NaN             NaN
# 1950    35   0.995       0.664       0.020           0.230
# 1960    64   0.974       0.599       0.053           0.231
# 1970    25   0.967       0.598       0.069           0.241
# 1980    28   0.961       0.529       0.094           0.236
# 1990    29   0.979       0.600       0.071           0.244
# 2000     8   0.989       0.617       0.017           0.247
# 2010     4   0.998       0.517       0.002           0.161

# %% [markdown]
# ## 10 — Failure modes
#
# Three patterns worth distinguishing:
#
# 1. **Pure downbeat collapse** — beats ≥ 0.8 but downbeats ≈ 0.
#    Phase ambiguity: the model found the pulse but locked onto the wrong bar position.
# 2. **Half-time / double-time** — count ratio outside [0.7, 1.4].
# 3. **Total miss** — both metrics < 0.5 (rubato, very sparse drumming, etc.).

# %%
phase_fail   = df[(df['beat_F-measure'] > 0.8) & (df['downbeat_F-measure'] < 0.2)]
halftime     = df[(df['beat_count_ratio'] < 0.7) | (df['beat_count_ratio'] > 1.4)]
total_miss   = df[(df['beat_F-measure'] < 0.5) & (df['downbeat_F-measure'] < 0.5)]

summary = pd.DataFrame({
    'failure_mode': ['phase / downbeat collapse', 'half- or double-time beats', 'total miss'],
    'n_tracks':     [len(phase_fail), len(halftime), len(total_miss)],
    'pct':          [len(phase_fail)/len(df)*100, len(halftime)/len(df)*100, len(total_miss)/len(df)*100],
})

fig, ax = plt.subplots(figsize=(11, 3.5))
ax.barh(summary['failure_mode'], summary['n_tracks'],
        color=['#e67e22','#f39c12','#c0392b'])
for i, (n, p) in enumerate(zip(summary['n_tracks'], summary['pct'])):
    ax.text(n + 5, i, f'{n} ({p:.1f}%)', va='center', fontsize=11)
ax.set_xlabel('# tracks'); ax.set_title('Failure-mode counts')
ax.invert_yaxis(); plt.tight_layout(); plt.show()

summary
# Out:
#                  failure_mode  n_tracks       pct
# 0   phase / downbeat collapse         5  2.577320
# 1  half- or double-time beats         2  1.030928
# 2                  total miss         0  0.000000

# %%
print('—— phase-collapse exemplars (beats good, downbeats failed) ——')
phase_fail.nsmallest(10, 'downbeat_F-measure')[
    ['track_id','beat_F-measure','downbeat_F-measure','beat_count_ratio','downbeat_count_ratio']
]
# Out:
# —— phase-collapse exemplars (beats good, downbeats failed) ——
#                                               track_id  beat_F-measure  \
# 162  powellb-bluesinthecloset-pettifordoclarkek-196...        0.959147
# 86     hollandd-interface-joneshhigginsb-1989-56f4aaf0        1.000000
# 150    petersono-iloveyou-brownrthigpene-1961-5c99390e        0.941839
# 192  waltonc-thenewestblues-williamsdhigginsb-1992-...        1.000000
# 87   hollandd-traneconnections-joneshhigginsb-1989-...        1.000000
#
#      downbeat_F-measure  beat_count_ratio  downbeat_count_ratio
# 162            0.000000          1.003367              1.000000
# 86             0.055944          1.000000              1.166667
# 150            0.099291          1.003584              1.130435
# 192            0.151057          1.000000              1.875000
# 87             0.163743          1.000000              1.521127

# %%
print('—— half/double-time exemplars (count ratio far from 1.0) ——')
halftime.assign(abs_dev=lambda d: (d['beat_count_ratio'] - 1).abs())\
        .nlargest(10, 'abs_dev')[
            ['track_id','n_gt_beats','n_pred_beats','beat_count_ratio','beat_F-measure']
        ]
# Out:
# —— half/double-time exemplars (count ratio far from 1.0) ——
#                                               track_id  n_gt_beats  \
# 133     monkt-aprilinparis-rameygblakeya-1949-c50b1c36         459
# 12   brownr-myheartstoodstill-smithpbellsonl-1978-d...         251
#
#      n_pred_beats  beat_count_ratio  beat_F-measure
# 133           230          0.501089        0.666667
# 12            126          0.501992        0.666667

# %% [markdown]
# ## 11 — Estimated tempo from predicted beats
#
# We don't have ground-truth tempo per track, but we can read the predicted
# beat times back from `results/preds/*.npz` and compute the median IBI
# (inter-beat-interval) → tempo. This gives a sense of the tempo range the
# model is operating over and whether the *worst* tracks cluster at tempo
# extremes.

# %%
def estimate_tempo_from_npz(track_id):
    p = PREDS_DIR / f'{track_id}.npz'
    if not p.exists():
        return np.nan
    try:
        data = np.load(p)
        beats = data['beats']
        if len(beats) < 4:
            return np.nan
        ibis = np.diff(beats)
        ibis = ibis[(ibis > 0.1) & (ibis < 2.0)]
        if len(ibis) == 0:
            return np.nan
        return 60.0 / np.median(ibis)
    except Exception:
        return np.nan

df['est_bpm'] = df['track_id'].apply(estimate_tempo_from_npz)
valid_bpm = df['est_bpm'].dropna()
print(f'Recovered tempo for {len(valid_bpm)}/{len(df)} tracks   '
      f'(median {valid_bpm.median():.1f} BPM, p5 {valid_bpm.quantile(0.05):.1f}, '
      f'p95 {valid_bpm.quantile(0.95):.1f})')
# Out:
# Recovered tempo for 194/194 tracks   (median 187.5 BPM, p5 107.1, p95 272.7)

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 5))

sns.histplot(valid_bpm.clip(40, 320), bins=50, color='#16a085', ax=axes[0], edgecolor='white')
axes[0].axvline(valid_bpm.median(), color='black', lw=1.5, label=f'median {valid_bpm.median():.0f} BPM')
axes[0].set_title('Estimated tempo distribution'); axes[0].set_xlabel('BPM'); axes[0].legend()

sns.scatterplot(data=df.dropna(subset=['est_bpm']),
                x='est_bpm', y='beat_F-measure', alpha=0.35, s=18,
                color='#3498db', label='beat F', ax=axes[1])
sns.scatterplot(data=df.dropna(subset=['est_bpm']),
                x='est_bpm', y='downbeat_F-measure', alpha=0.35, s=18,
                color='#e74c3c', label='downbeat F', ax=axes[1])
axes[1].set_xlim(40, 320); axes[1].set_ylim(0, 1.05)
axes[1].set_xlabel('Estimated BPM'); axes[1].set_ylabel('F-measure')
axes[1].set_title('Performance vs. tempo')
plt.tight_layout(); plt.show()

# %% [markdown]
# ## 12 — Hardest tracks
#
# Top-10 worst by each headline metric. Use these as candidates for the
# single-track investigation cells below.

# %%
worst_beat = (df[df['status'] == 'ok']
                .nsmallest(10, 'beat_F-measure')
                [['track_id','beat_F-measure','downbeat_F-measure',
                  'beat_count_ratio','est_bpm']])
worst_beat.style.background_gradient(cmap='Reds_r', subset=['beat_F-measure'])\
                 .format({'beat_F-measure':'{:.3f}','downbeat_F-measure':'{:.3f}',
                          'beat_count_ratio':'{:.2f}','est_bpm':'{:.0f}'})
# Out:
# <style type="text/css">
# #T_5b370_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_5b370_row1_col1 {
#   background-color: #c9181d;
#   color: #f1f1f1;
# }
# #T_5b370_row2_col1, #T_5b370_row3_col1 {
#   background-color: #ee3a2c;
#   color: #f1f1f1;
# }
# #T_5b370_row4_col1 {
#   background-color: #fa6547;
#   color: #f1f1f1;
# }
# #T_5b370_row5_col1 {
#   background-color: #fc9879;
#   color: #000000;
# }
# #T_5b370_row6_col1 {
#   background-color: #fdd2bf;
#   color: #000000;
# }
# #T_5b370_row7_col1 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_5b370_row8_col1 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_5b370_row9_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_5b370">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b370_level0_col0" class="col_heading level0 col0" >track_id</th>
#       <th id="T_5b370_level0_col1" class="col_heading level0 col1" >beat_F-measure</th>
#       <th id="T_5b370_level0_col2" class="col_heading level0 col2" >downbeat_F-measure</th>
#       <th id="T_5b370_level0_col3" class="col_heading level0 col3" >beat_count_ratio</th>
#       <th id="T_5b370_level0_col4" class="col_heading level0 col4" >est_bpm</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b370_level0_row0" class="row_heading level0 row0" >181</th>
#       <td id="T_5b370_row0_col0" class="data row0 col0" >tynerm-darnthatdream-sharpeascotta-1989-6cc187a8</td>
#       <td id="T_5b370_row0_col1" class="data row0 col1" >0.531</td>
#       <td id="T_5b370_row0_col2" class="data row0 col2" >0.185</td>
#       <td id="T_5b370_row0_col3" class="data row0 col3" >0.82</td>
#       <td id="T_5b370_row0_col4" class="data row0 col4" >125</td>
#     </tr>
#     <tr>
#       <th id="T_5b370_level0_row1" class="row_heading level0 row1" >110</th>
#       <td id="T_5b370_row1_col0" class="data row1 col0" >jarrettk-ithoughtaboutyou-peacockgdejohnettej-1993-340a16bd</td>
#       <td id="T_5b370_row1_col1" class="data row1 col1" >0.619</td>
#       <td id="T_5b370_row1_col2" class="data row1 col2" >0.206</td>
#       <td id="T_5b370_row1_col3" class="data row1 col3" >0.84</td>
#       <td id="T_5b370_row1_col4" class="data row1 col4" >107</td>
#     </tr>
#     <tr>
#       <th id="T_5b370_level0_row2" class="row_heading level0 row2" >12</th>
#       <td id="T_5b370_row2_col0" class="data row2 col0" >brownr-myheartstoodstill-smithpbellsonl-1978-d3d8fdc4</td>
#       <td id="T_5b370_row2_col1" class="data row2 col1" >0.667</td>
#       <td id="T_5b370_row2_col2" class="data row2 col2" >0.713</td>
#       <td id="T_5b370_row2_col3" class="data row2 col3" >0.50</td>
#       <td id="T_5b370_row2_col4" class="data row2 col4" >120</td>
#     </tr>
#     <tr>
#       <th id="T_5b370_level0_row3" class="row_heading level0 row3" >133</th>
#       <td id="T_5b370_row3_col0" class="data row3 col0" >monkt-aprilinparis-rameygblakeya-1949-c50b1c36</td>
#       <td id="T_5b370_row3_col1" class="data row3 col1" >0.667</td>
#       <td id="T_5b370_row3_col2" class="data row3 col2" >0.650</td>
#       <td id="T_5b370_row3_col3" class="data row3 col3" >0.50</td>
#       <td id="T_5b370_row3_col4" class="data row3 col4" >125</td>
#     </tr>
#     <tr>
#       <th id="T_5b370_level0_row4" class="row_heading level0 row4" >8</th>
#       <td id="T_5b370_row4_col0" class="data row4 col0" >bleyp-syndrome-swallowslap-1963-e13458a9</td>
#       <td id="T_5b370_row4_col1" class="data row4 col1" >0.707</td>
#       <td id="T_5b370_row4_col2" class="data row4 col2" >0.262</td>
#       <td id="T_5b370_row4_col3" class="data row4 col3" >1.14</td>
#       <td id="T_5b370_row4_col4" class="data row4 col4" >214</td>
#     </tr>
#     <tr>
#       <th id="T_5b370_level0_row5" class="row_heading level0 row5" >101</th>
#       <td id="T_5b370_row5_col0" class="data row5 col0" >jamala-yougotomyhead-crosbyifournierv-1960-5a0737d3</td>
#       <td id="T_5b370_row5_col1" class="data row5 col1" >0.764</td>
#       <td id="T_5b370_row5_col2" class="data row5 col2" >0.317</td>
#       <td id="T_5b370_row5_col3" class="data row5 col3" >1.00</td>
#       <td id="T_5b370_row5_col4" class="data row5 col4" >136</td>
#     </tr>
#     <tr>
#       <th id="T_5b370_level0_row6" class="row_heading level0 row6" >24</th>
#       <td id="T_5b370_row6_col0" class="data row6 col0" >coreac-sophisticatedlady-patituccijweckld-1989-85cb4d64</td>
#       <td id="T_5b370_row6_col1" class="data row6 col1" >0.832</td>
#       <td id="T_5b370_row6_col2" class="data row6 col2" >0.461</td>
#       <td id="T_5b370_row6_col3" class="data row6 col3" >0.94</td>
#       <td id="T_5b370_row6_col4" class="data row6 col4" >73</td>
#     </tr>
#     <tr>
#       <th id="T_5b370_level0_row7" class="row_heading level0 row7" >4</th>
#       <td id="T_5b370_row7_col0" class="data row7 col0" >barronk-thereisnogreaterlove-williamsbrileyb-1984-90d41f7e</td>
#       <td id="T_5b370_row7_col1" class="data row7 col1" >0.873</td>
#       <td id="T_5b370_row7_col2" class="data row7 col2" >0.474</td>
#       <td id="T_5b370_row7_col3" class="data row7 col3" >1.01</td>
#       <td id="T_5b370_row7_col4" class="data row7 col4" >214</td>
#     </tr>
#     <tr>
#       <th id="T_5b370_level0_row8" class="row_heading level0 row8" >111</th>
#       <td id="T_5b370_row8_col0" class="data row8 col0" >jarrettk-lisbonstomp-hadencmotianp-1968-8994c848</td>
#       <td id="T_5b370_row8_col1" class="data row8 col1" >0.878</td>
#       <td id="T_5b370_row8_col2" class="data row8 col2" >0.376</td>
#       <td id="T_5b370_row8_col3" class="data row8 col3" >1.13</td>
#       <td id="T_5b370_row8_col4" class="data row8 col4" >111</td>
#     </tr>
#     <tr>
#       <th id="T_5b370_level0_row9" class="row_heading level0 row9" >94</th>
#       <td id="T_5b370_row9_col0" class="data row9 col0" >jamala-angeleyes-crosbyifournierv-1961-69a58683</td>
#       <td id="T_5b370_row9_col1" class="data row9 col1" >0.895</td>
#       <td id="T_5b370_row9_col2" class="data row9 col2" >0.355</td>
#       <td id="T_5b370_row9_col3" class="data row9 col3" >1.01</td>
#       <td id="T_5b370_row9_col4" class="data row9 col4" >143</td>
#     </tr>
#   </tbody>
# </table>

# %%
worst_db = (df[df['status'] == 'ok']
              .nsmallest(10, 'downbeat_F-measure')
              [['track_id','beat_F-measure','downbeat_F-measure',
                'downbeat_count_ratio','est_bpm']])
worst_db.style.background_gradient(cmap='Reds_r', subset=['downbeat_F-measure'])\
                .format({'beat_F-measure':'{:.3f}','downbeat_F-measure':'{:.3f}',
                         'downbeat_count_ratio':'{:.2f}','est_bpm':'{:.0f}'})
# Out:
# <style type="text/css">
# #T_cd504_row0_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_cd504_row1_col2 {
#   background-color: #bf151b;
#   color: #f1f1f1;
# }
# #T_cd504_row2_col2 {
#   background-color: #f03d2d;
#   color: #f1f1f1;
# }
# #T_cd504_row3_col2 {
#   background-color: #fc8262;
#   color: #f1f1f1;
# }
# #T_cd504_row4_col2 {
#   background-color: #fc9373;
#   color: #000000;
# }
# #T_cd504_row5_col2 {
#   background-color: #fcae92;
#   color: #000000;
# }
# #T_cd504_row6_col2 {
#   background-color: #fcc4ad;
#   color: #000000;
# }
# #T_cd504_row7_col2 {
#   background-color: #fdc6b0;
#   color: #000000;
# }
# #T_cd504_row8_col2 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_cd504_row9_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_cd504">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd504_level0_col0" class="col_heading level0 col0" >track_id</th>
#       <th id="T_cd504_level0_col1" class="col_heading level0 col1" >beat_F-measure</th>
#       <th id="T_cd504_level0_col2" class="col_heading level0 col2" >downbeat_F-measure</th>
#       <th id="T_cd504_level0_col3" class="col_heading level0 col3" >downbeat_count_ratio</th>
#       <th id="T_cd504_level0_col4" class="col_heading level0 col4" >est_bpm</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd504_level0_row0" class="row_heading level0 row0" >162</th>
#       <td id="T_cd504_row0_col0" class="data row0 col0" >powellb-bluesinthecloset-pettifordoclarkek-1960-cf0f2bb4</td>
#       <td id="T_cd504_row0_col1" class="data row0 col1" >0.959</td>
#       <td id="T_cd504_row0_col2" class="data row0 col2" >0.000</td>
#       <td id="T_cd504_row0_col3" class="data row0 col3" >1.00</td>
#       <td id="T_cd504_row0_col4" class="data row0 col4" >200</td>
#     </tr>
#     <tr>
#       <th id="T_cd504_level0_row1" class="row_heading level0 row1" >86</th>
#       <td id="T_cd504_row1_col0" class="data row1 col0" >hollandd-interface-joneshhigginsb-1989-56f4aaf0</td>
#       <td id="T_cd504_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_cd504_row1_col2" class="data row1 col2" >0.056</td>
#       <td id="T_cd504_row1_col3" class="data row1 col3" >1.17</td>
#       <td id="T_cd504_row1_col4" class="data row1 col4" >188</td>
#     </tr>
#     <tr>
#       <th id="T_cd504_level0_row2" class="row_heading level0 row2" >150</th>
#       <td id="T_cd504_row2_col0" class="data row2 col0" >petersono-iloveyou-brownrthigpene-1961-5c99390e</td>
#       <td id="T_cd504_row2_col1" class="data row2 col1" >0.942</td>
#       <td id="T_cd504_row2_col2" class="data row2 col2" >0.099</td>
#       <td id="T_cd504_row2_col3" class="data row2 col3" >1.13</td>
#       <td id="T_cd504_row2_col4" class="data row2 col4" >150</td>
#     </tr>
#     <tr>
#       <th id="T_cd504_level0_row3" class="row_heading level0 row3" >192</th>
#       <td id="T_cd504_row3_col0" class="data row3 col0" >waltonc-thenewestblues-williamsdhigginsb-1992-e10c3edf</td>
#       <td id="T_cd504_row3_col1" class="data row3 col1" >1.000</td>
#       <td id="T_cd504_row3_col2" class="data row3 col2" >0.151</td>
#       <td id="T_cd504_row3_col3" class="data row3 col3" >1.88</td>
#       <td id="T_cd504_row3_col4" class="data row3 col4" >176</td>
#     </tr>
#     <tr>
#       <th id="T_cd504_level0_row4" class="row_heading level0 row4" >87</th>
#       <td id="T_cd504_row4_col0" class="data row4 col0" >hollandd-traneconnections-joneshhigginsb-1989-a13fb393</td>
#       <td id="T_cd504_row4_col1" class="data row4 col1" >1.000</td>
#       <td id="T_cd504_row4_col2" class="data row4 col2" >0.164</td>
#       <td id="T_cd504_row4_col3" class="data row4 col3" >1.52</td>
#       <td id="T_cd504_row4_col4" class="data row4 col4" >200</td>
#     </tr>
#     <tr>
#       <th id="T_cd504_level0_row5" class="row_heading level0 row5" >181</th>
#       <td id="T_cd504_row5_col0" class="data row5 col0" >tynerm-darnthatdream-sharpeascotta-1989-6cc187a8</td>
#       <td id="T_cd504_row5_col1" class="data row5 col1" >0.531</td>
#       <td id="T_cd504_row5_col2" class="data row5 col2" >0.185</td>
#       <td id="T_cd504_row5_col3" class="data row5 col3" >1.24</td>
#       <td id="T_cd504_row5_col4" class="data row5 col4" >125</td>
#     </tr>
#     <tr>
#       <th id="T_cd504_level0_row6" class="row_heading level0 row6" >98</th>
#       <td id="T_cd504_row6_col0" class="data row6 col0" >jamala-ongreendolphinstreet-crosbyifournierv-1959-8ff3c6f7</td>
#       <td id="T_cd504_row6_col1" class="data row6 col1" >1.000</td>
#       <td id="T_cd504_row6_col2" class="data row6 col2" >0.203</td>
#       <td id="T_cd504_row6_col3" class="data row6 col3" >1.84</td>
#       <td id="T_cd504_row6_col4" class="data row6 col4" >187</td>
#     </tr>
#     <tr>
#       <th id="T_cd504_level0_row7" class="row_heading level0 row7" >110</th>
#       <td id="T_cd504_row7_col0" class="data row7 col0" >jarrettk-ithoughtaboutyou-peacockgdejohnettej-1993-340a16bd</td>
#       <td id="T_cd504_row7_col1" class="data row7 col1" >0.619</td>
#       <td id="T_cd504_row7_col2" class="data row7 col2" >0.206</td>
#       <td id="T_cd504_row7_col3" class="data row7 col3" >2.36</td>
#       <td id="T_cd504_row7_col4" class="data row7 col4" >107</td>
#     </tr>
#     <tr>
#       <th id="T_cd504_level0_row8" class="row_heading level0 row8" >56</th>
#       <td id="T_cd504_row8_col0" class="data row8 col0" >evansb-turnoutthestars-gomezemorellm-1974-c60c9a34</td>
#       <td id="T_cd504_row8_col1" class="data row8 col1" >0.996</td>
#       <td id="T_cd504_row8_col2" class="data row8 col2" >0.237</td>
#       <td id="T_cd504_row8_col3" class="data row8 col3" >2.69</td>
#       <td id="T_cd504_row8_col4" class="data row8 col4" >150</td>
#     </tr>
#     <tr>
#       <th id="T_cd504_level0_row9" class="row_heading level0 row9" >42</th>
#       <td id="T_cd504_row9_col0" class="data row9 col0" >evansb-minority-jonessjoep-1958-687403fa</td>
#       <td id="T_cd504_row9_col1" class="data row9 col1" >1.000</td>
#       <td id="T_cd504_row9_col2" class="data row9 col2" >0.261</td>
#       <td id="T_cd504_row9_col3" class="data row9 col3" >2.36</td>
#       <td id="T_cd504_row9_col4" class="data row9 col4" >231</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ---
# ## 13 — Single-track investigation
#
# These cells require the audio + model stacks (`librosa`, `soxr`, `torch`).
# If the imports at the top failed they will be skipped automatically.

# %%
def play_with_clicks(audio_path, beats, downbeats=None):
    if not AUDIO_OK:
        print('audio stack unavailable; skipping playback.')
        return None
    y, sr = librosa.load(audio_path)
    clicks = librosa.clicks(times=beats, sr=sr, length=len(y),
                            click_freq=1000, click_duration=0.1)
    if downbeats is not None:
        db_clicks = librosa.clicks(times=downbeats, sr=sr, length=len(y),
                                   click_freq=500, click_duration=0.1)
        clicks = clicks + db_clicks
    return ipd.Audio(y + clicks * 0.5, rate=sr)

# %% [markdown]
# ### 13a — Bill Evans, *Like Someone in Love* (1980) — phase-collapse case
#
# Beats are tracked well but downbeats fail completely (downbeat F ≈ 0).

# %%
target_track = 'evansb-likesomeoneinlove-johnsonmlabarberaj-1980-c67ffd5a'
df[df['track_id'] == target_track][
    ['track_id','beat_F-measure','downbeat_F-measure',
     'n_gt_beats','n_pred_beats','n_gt_downbeats','n_pred_downbeats']
]
# Out:
# Empty DataFrame
# Columns: [track_id, beat_F-measure, downbeat_F-measure, n_gt_beats, n_pred_beats, n_gt_downbeats, n_pred_downbeats]
# Index: []

# %%
if MODEL_OK:
    checkpoint_path = './beat_this/checkpoint/final0.ckpt'
    audio_path = './test_audio/evansb-thetwolonelypeople-johnsonmlabarberaj-1980-e5016fe2.wav'
    print(f"Running inference on: {audio_path}")
    beat, downbeat = run_beat_this(checkpoint_path=checkpoint_path, audio_path=audio_path)
    plot_beats(audio_path, beat, downbeat)
else:
    print('model stack unavailable; install soxr/torch to run inference.')
# Out:
# Running inference on: ./test_audio/evansb-thetwolonelypeople-johnsonmlabarberaj-1980-e5016fe2.wav
# Downloading: "https://cloud.cp.jku.at/public.php/dav/files/7ik4RrBKTS273gp/./beat_this/checkpoint/final0.ckpt.ckpt" to /Users/robbietylman/.cache/torch/hub/checkpoints/beat_this-./beat_this/checkpoint/final0.ckpt.ckpt
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/GitHub/MIR-Jazz-Beat-Tracking/evaluation/../beat_this/inference.py:30, in load_checkpoint(checkpoint_path, device)
#      29     weights_only = {"weights_only": True} if torch.__version__ >= "2" else {}
# ---> 30     return torch.load(checkpoint_path, map_location=device, **weights_only)
#      31 except FileNotFoundError:
#
# File /opt/anaconda3/lib/python3.13/site-packages/torch/serialization.py:1500, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1498     pickle_load_args["encoding"] = "utf-8"
# -> 1500 with _open_file_like(f, "rb") as opened_file:
#    1501     if _is_zipfile(opened_file):
#    1502         # The zipfile reader is going to advance the current file position.
#    1503         # If we want to actually tail call to torch.jit.load, we need to
#    1504         # reset back to the original position.
#
# File /opt/anaconda3/lib/python3.13/site-packages/torch/serialization.py:768, in _open_file_like(name_or_buffer, mode)
#     767 if _is_path(name_or_buffer):
# --> 768     return _open_file(name_or_buffer, mode)
#     769 else:
#
# File /opt/anaconda3/lib/python3.13/site-packages/torch/serialization.py:749, in _open_file.__init__(self, name, mode)
#     748 def __init__(self, name: str | os.PathLike[str], mode: str) -> None:
# --> 749     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: './beat_this/checkpoint/final0.ckpt'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~/GitHub/MIR-Jazz-Beat-Tracking/evaluation/../beat_this/inference.py:44, in load_checkpoint(checkpoint_path, device)
#      43         file_name = None
# ---> 44     return torch.hub.load_state_dict_from_url(
#      45         checkpoint_url,
#      46         file_name=file_name,
#      47         map_location=device,
#      48     )
#      49 except Exception:
#
# File /opt/anaconda3/lib/python3.13/site-packages/torch/hub.py:880, in load_state_dict_from_url(url, model_dir, map_location, progress, check_hash, file_name, weights_only)
#     879         hash_prefix = r.group(1) if r else None
# --> 880     download_url_to_file(url, cached_file, hash_prefix, progress=progress)
#     882 if _is_legacy_zip_format(cached_file):
#
# File /opt/anaconda3/lib/python3.13/site-packages/torch/hub.py:728, in download_url_to_file(url, dst, hash_prefix, progress)
#     727 try:
# --> 728     f = open(tmp_dst, "w+b")  # noqa: SIM115
#     729 except FileExistsError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/robbietylman/.cache/torch/hub/checkpoints/beat_this-./beat_this/checkpoint/final0.ckpt.ckpt.7c58348866094d65a93fcf7196dafe52.partial'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[75], line 5
#       3     audio_path = './test_audio/evansb-thetwolonelypeople-johnsonmlabarberaj-1980-e5016fe2.wav'
#       4     print(f"Running inference on: {audio_path}")
# ----> 5     beat, downbeat = run_beat_this(checkpoint_path=checkpoint_path, audio_path=audio_path)
#       6     plot_beats(audio_path, beat, downbeat)
#       7 else:
#
# File ~/GitHub/MIR-Jazz-Beat-Tracking/evaluation/../scripts/run_beat_this.py:6, in run_beat_this(checkpoint_path, audio_path)
#       5 def run_beat_this(checkpoint_path, audio_path):
# ----> 6     file2beats = File2Beats(checkpoint_path=checkpoint_path, device="cpu", dbn=False)
#       7     beats, downbeats = file2beats(audio_path)
#       8     return beats, downbeats
#
# File ~/GitHub/MIR-Jazz-Beat-Tracking/evaluation/../beat_this/inference.py:298, in Audio2Beats.__init__(self, checkpoint_path, device, float16, dbn)
#     295 def __init__(
#     296     self, checkpoint_path="final0", device="cpu", float16=False, dbn=False
#     297 ):
# --> 298     super().__init__(checkpoint_path, device, float16)
#     299     self.frames2beats = Postprocessor(type="dbn" if dbn else "minimal")
#
# File ~/GitHub/MIR-Jazz-Beat-Tracking/evaluation/../beat_this/inference.py:266, in Audio2Frames.__init__(self, checkpoint_path, device, float16)
#     265 def __init__(self, checkpoint_path="final0", device="cpu", float16=False):
# --> 266     super().__init__(checkpoint_path, device, float16)
#     267     self.spect = LogMelSpect(device=self.device)
#
# File ~/GitHub/MIR-Jazz-Beat-Tracking/evaluation/../beat_this/inference.py:242, in Spect2Frames.__init__(self, checkpoint_path, device, float16)
#     240 self.device = torch.device(device)
#     241 self.float16 = float16
# --> 242 self.model = load_model(checkpoint_path, self.device)
#
# File ~/GitHub/MIR-Jazz-Beat-Tracking/evaluation/../beat_this/inference.py:70, in load_model(checkpoint_path, device)
#      59 """
#      60 Load a BeatThis model from a checkpoint.
#      61
#    (...)
#      67     BeatThis: The loaded model.
#      68 """
#      69 if checkpoint_path is not None:
# ---> 70     checkpoint = load_checkpoint(checkpoint_path, device)
#      71     # Retrieve the model hyperparameters as it could be the small model
#      72     hparams = checkpoint["hyper_parameters"]
#
# File ~/GitHub/MIR-Jazz-Beat-Tracking/evaluation/../beat_this/inference.py:50, in load_checkpoint(checkpoint_path, device)
#      44     return torch.hub.load_state_dict_from_url(
#      45         checkpoint_url,
#      46         file_name=file_name,
#      47         map_location=device,
#      48     )
#      49 except Exception:
# ---> 50     raise ValueError(
#      51         "Could not load the checkpoint given the provided name",
#      52         checkpoint_path,
#      53     )
#
# ValueError: ('Could not load the checkpoint given the provided name', './beat_this/checkpoint/final0.ckpt')

# %%
if MODEL_OK and AUDIO_OK:
    display(play_with_clicks(audio_path, beat, downbeat))

# %% [markdown]
# ### 13b — Bill Evans, *The Two Lonely People* (1980) — lowest beat F-measure
#
# Around 30 s the bass drops to half-time and the model halves its tempo with it.

# %%
print('Top 5 tracks with lowest beat F-measure:')
df[['track_id','beat_F-measure','downbeat_F-measure']]\
  .sort_values('beat_F-measure').head()
# Out:
# Top 5 tracks with lowest beat F-measure:
#                                               track_id  beat_F-measure  \
# 181   tynerm-darnthatdream-sharpeascotta-1989-6cc187a8        0.530769
# 110  jarrettk-ithoughtaboutyou-peacockgdejohnettej-...        0.619048
# 133     monkt-aprilinparis-rameygblakeya-1949-c50b1c36        0.666667
# 12   brownr-myheartstoodstill-smithpbellsonl-1978-d...        0.666667
# 8             bleyp-syndrome-swallowslap-1963-e13458a9        0.707483
#
#      downbeat_F-measure
# 181            0.185185
# 110            0.206186
# 133            0.650000
# 12             0.712871
# 8              0.262295

# %%
if MODEL_OK:
    checkpoint_path = './beat_this/checkpoint/final0.ckpt'
    audio_path = './test_audio/evansb-thetwolonelypeople-johnsonmlabarberaj-1980-e5016fe2.wav'
    print(f"Running inference on: {audio_path}")
    beat, downbeat = run_beat_this(checkpoint_path=checkpoint_path, audio_path=audio_path)
    plot_beats(audio_path, beat, downbeat)
else:
    print('model stack unavailable; install soxr/torch to run inference.')
# Out:
# model stack unavailable; install soxr/torch to run inference.

# %%
if MODEL_OK and AUDIO_OK:
    display(play_with_clicks(audio_path, beat, downbeat))

# %% [markdown]
# *Observation: at ~30 s the walking bass momentarily implies half-time and the
# model latches on, halving its predicted tempo until the cymbal pattern reasserts.*

# %% [markdown]
# ---
# ## 14 — Worst-performing tracks
#
# This final section turns the failure list into a compact diagnostic view. It ranks the
# lowest beat F-measure tracks, compares their beat/downbeat scores, and overlays cached
# predictions from `preds/*.npz` against the JTD reference annotations in
# `../jazz-trio-database-v02/<track_id>/beats.csv`.

# %%
WORST_N = 12
JTD_ROOT = Path('../jazz-trio-database-v02')

worst_tracks = (
    df[df['status'].eq('ok')]
      .assign(
          beat_error=lambda d: 1 - d['beat_F-measure'],
          downbeat_error=lambda d: 1 - d['downbeat_F-measure'],
          abs_beat_count_diff=lambda d: d['beat_count_diff'].abs(),
          abs_downbeat_count_diff=lambda d: d['downbeat_count_diff'].abs(),
      )
      .nsmallest(WORST_N, 'beat_F-measure')
      .copy()
)

worst_cols = [
    'track_id', 'bandleader', 'year', 'time_signature', 'tempo',
    'beat_F-measure', 'downbeat_F-measure',
    'n_gt_beats', 'n_pred_beats', 'beat_count_ratio',
    'n_gt_downbeats', 'n_pred_downbeats', 'downbeat_count_ratio',
]
available_worst_cols = [c for c in worst_cols if c in worst_tracks.columns]

print(f'Worst {len(worst_tracks)} tracks by beat F-measure')
display(
    worst_tracks[available_worst_cols]
      .style
      .background_gradient(cmap='Reds_r', subset=['beat_F-measure', 'downbeat_F-measure'])
      .format({
          'tempo': '{:.1f}',
          'beat_F-measure': '{:.3f}',
          'downbeat_F-measure': '{:.3f}',
          'beat_count_ratio': '{:.2f}',
          'downbeat_count_ratio': '{:.2f}',
      })
)
# Out:
# Worst 12 tracks by beat F-measure
# <style type="text/css">
# #T_bc5ed_row0_col5, #T_bc5ed_row0_col6 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_bc5ed_row1_col5 {
#   background-color: #c7171c;
#   color: #f1f1f1;
# }
# #T_bc5ed_row1_col6 {
#   background-color: #7a0510;
#   color: #f1f1f1;
# }
# #T_bc5ed_row2_col5, #T_bc5ed_row3_col5, #T_bc5ed_row8_col6 {
#   background-color: #eb372a;
#   color: #f1f1f1;
# }
# #T_bc5ed_row2_col6, #T_bc5ed_row11_col5 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_bc5ed_row3_col6 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_bc5ed_row4_col5 {
#   background-color: #f85f43;
#   color: #f1f1f1;
# }
# #T_bc5ed_row4_col6 {
#   background-color: #ab1016;
#   color: #f1f1f1;
# }
# #T_bc5ed_row5_col5 {
#   background-color: #fc9070;
#   color: #000000;
# }
# #T_bc5ed_row5_col6 {
#   background-color: #ca181d;
#   color: #f1f1f1;
# }
# #T_bc5ed_row6_col5 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_bc5ed_row6_col6 {
#   background-color: #fb7151;
#   color: #f1f1f1;
# }
# #T_bc5ed_row7_col5 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_bc5ed_row7_col6 {
#   background-color: #fb7a5a;
#   color: #f1f1f1;
# }
# #T_bc5ed_row8_col5 {
#   background-color: #fee8de;
#   color: #000000;
# }
# #T_bc5ed_row9_col5 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_bc5ed_row9_col6 {
#   background-color: #e02c26;
#   color: #f1f1f1;
# }
# #T_bc5ed_row10_col5 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_bc5ed_row10_col6 {
#   background-color: #b51318;
#   color: #f1f1f1;
# }
# #T_bc5ed_row11_col6 {
#   background-color: #d42121;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bc5ed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc5ed_level0_col0" class="col_heading level0 col0" >track_id</th>
#       <th id="T_bc5ed_level0_col1" class="col_heading level0 col1" >bandleader</th>
#       <th id="T_bc5ed_level0_col2" class="col_heading level0 col2" >year</th>
#       <th id="T_bc5ed_level0_col3" class="col_heading level0 col3" >time_signature</th>
#       <th id="T_bc5ed_level0_col4" class="col_heading level0 col4" >tempo</th>
#       <th id="T_bc5ed_level0_col5" class="col_heading level0 col5" >beat_F-measure</th>
#       <th id="T_bc5ed_level0_col6" class="col_heading level0 col6" >downbeat_F-measure</th>
#       <th id="T_bc5ed_level0_col7" class="col_heading level0 col7" >n_gt_beats</th>
#       <th id="T_bc5ed_level0_col8" class="col_heading level0 col8" >n_pred_beats</th>
#       <th id="T_bc5ed_level0_col9" class="col_heading level0 col9" >beat_count_ratio</th>
#       <th id="T_bc5ed_level0_col10" class="col_heading level0 col10" >n_gt_downbeats</th>
#       <th id="T_bc5ed_level0_col11" class="col_heading level0 col11" >n_pred_downbeats</th>
#       <th id="T_bc5ed_level0_col12" class="col_heading level0 col12" >downbeat_count_ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc5ed_level0_row0" class="row_heading level0 row0" >181</th>
#       <td id="T_bc5ed_row0_col0" class="data row0 col0" >tynerm-darnthatdream-sharpeascotta-1989-6cc187a8</td>
#       <td id="T_bc5ed_row0_col1" class="data row0 col1" >McCoy Tyner</td>
#       <td id="T_bc5ed_row0_col2" class="data row0 col2" >1989</td>
#       <td id="T_bc5ed_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_bc5ed_row0_col4" class="data row0 col4" >162.5</td>
#       <td id="T_bc5ed_row0_col5" class="data row0 col5" >0.531</td>
#       <td id="T_bc5ed_row0_col6" class="data row0 col6" >0.185</td>
#       <td id="T_bc5ed_row0_col7" class="data row0 col7" >299</td>
#       <td id="T_bc5ed_row0_col8" class="data row0 col8" >245</td>
#       <td id="T_bc5ed_row0_col9" class="data row0 col9" >0.82</td>
#       <td id="T_bc5ed_row0_col10" class="data row0 col10" >75</td>
#       <td id="T_bc5ed_row0_col11" class="data row0 col11" >93</td>
#       <td id="T_bc5ed_row0_col12" class="data row0 col12" >1.24</td>
#     </tr>
#     <tr>
#       <th id="T_bc5ed_level0_row1" class="row_heading level0 row1" >110</th>
#       <td id="T_bc5ed_row1_col0" class="data row1 col0" >jarrettk-ithoughtaboutyou-peacockgdejohnettej-1993-340a16bd</td>
#       <td id="T_bc5ed_row1_col1" class="data row1 col1" >Keith Jarrett</td>
#       <td id="T_bc5ed_row1_col2" class="data row1 col2" >1993</td>
#       <td id="T_bc5ed_row1_col3" class="data row1 col3" >4</td>
#       <td id="T_bc5ed_row1_col4" class="data row1 col4" >207.3</td>
#       <td id="T_bc5ed_row1_col5" class="data row1 col5" >0.619</td>
#       <td id="T_bc5ed_row1_col6" class="data row1 col6" >0.206</td>
#       <td id="T_bc5ed_row1_col7" class="data row1 col7" >129</td>
#       <td id="T_bc5ed_row1_col8" class="data row1 col8" >109</td>
#       <td id="T_bc5ed_row1_col9" class="data row1 col9" >0.84</td>
#       <td id="T_bc5ed_row1_col10" class="data row1 col10" >33</td>
#       <td id="T_bc5ed_row1_col11" class="data row1 col11" >78</td>
#       <td id="T_bc5ed_row1_col12" class="data row1 col12" >2.36</td>
#     </tr>
#     <tr>
#       <th id="T_bc5ed_level0_row2" class="row_heading level0 row2" >12</th>
#       <td id="T_bc5ed_row2_col0" class="data row2 col0" >brownr-myheartstoodstill-smithpbellsonl-1978-d3d8fdc4</td>
#       <td id="T_bc5ed_row2_col1" class="data row2 col1" >Ray Brown</td>
#       <td id="T_bc5ed_row2_col2" class="data row2 col2" >1978</td>
#       <td id="T_bc5ed_row2_col3" class="data row2 col3" >4</td>
#       <td id="T_bc5ed_row2_col4" class="data row2 col4" >246.4</td>
#       <td id="T_bc5ed_row2_col5" class="data row2 col5" >0.667</td>
#       <td id="T_bc5ed_row2_col6" class="data row2 col6" >0.713</td>
#       <td id="T_bc5ed_row2_col7" class="data row2 col7" >251</td>
#       <td id="T_bc5ed_row2_col8" class="data row2 col8" >126</td>
#       <td id="T_bc5ed_row2_col9" class="data row2 col9" >0.50</td>
#       <td id="T_bc5ed_row2_col10" class="data row2 col10" >63</td>
#       <td id="T_bc5ed_row2_col11" class="data row2 col11" >49</td>
#       <td id="T_bc5ed_row2_col12" class="data row2 col12" >0.78</td>
#     </tr>
#     <tr>
#       <th id="T_bc5ed_level0_row3" class="row_heading level0 row3" >133</th>
#       <td id="T_bc5ed_row3_col0" class="data row3 col0" >monkt-aprilinparis-rameygblakeya-1949-c50b1c36</td>
#       <td id="T_bc5ed_row3_col1" class="data row3 col1" >Thelonious Monk</td>
#       <td id="T_bc5ed_row3_col2" class="data row3 col2" >1949</td>
#       <td id="T_bc5ed_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_bc5ed_row3_col4" class="data row3 col4" >251.9</td>
#       <td id="T_bc5ed_row3_col5" class="data row3 col5" >0.667</td>
#       <td id="T_bc5ed_row3_col6" class="data row3 col6" >0.650</td>
#       <td id="T_bc5ed_row3_col7" class="data row3 col7" >459</td>
#       <td id="T_bc5ed_row3_col8" class="data row3 col8" >230</td>
#       <td id="T_bc5ed_row3_col9" class="data row3 col9" >0.50</td>
#       <td id="T_bc5ed_row3_col10" class="data row3 col10" >115</td>
#       <td id="T_bc5ed_row3_col11" class="data row3 col11" >221</td>
#       <td id="T_bc5ed_row3_col12" class="data row3 col12" >1.92</td>
#     </tr>
#     <tr>
#       <th id="T_bc5ed_level0_row4" class="row_heading level0 row4" >8</th>
#       <td id="T_bc5ed_row4_col0" class="data row4 col0" >bleyp-syndrome-swallowslap-1963-e13458a9</td>
#       <td id="T_bc5ed_row4_col1" class="data row4 col1" >Paul Bley</td>
#       <td id="T_bc5ed_row4_col2" class="data row4 col2" >1963</td>
#       <td id="T_bc5ed_row4_col3" class="data row4 col3" >4</td>
#       <td id="T_bc5ed_row4_col4" class="data row4 col4" >206.4</td>
#       <td id="T_bc5ed_row4_col5" class="data row4 col5" >0.707</td>
#       <td id="T_bc5ed_row4_col6" class="data row4 col6" >0.262</td>
#       <td id="T_bc5ed_row4_col7" class="data row4 col7" >496</td>
#       <td id="T_bc5ed_row4_col8" class="data row4 col8" >566</td>
#       <td id="T_bc5ed_row4_col9" class="data row4 col9" >1.14</td>
#       <td id="T_bc5ed_row4_col10" class="data row4 col10" >124</td>
#       <td id="T_bc5ed_row4_col11" class="data row4 col11" >441</td>
#       <td id="T_bc5ed_row4_col12" class="data row4 col12" >3.56</td>
#     </tr>
#     <tr>
#       <th id="T_bc5ed_level0_row5" class="row_heading level0 row5" >101</th>
#       <td id="T_bc5ed_row5_col0" class="data row5 col0

# %%
plot_df = worst_tracks.sort_values('beat_F-measure', ascending=True).copy()
plot_df['short_id'] = plot_df['track_id'].str.replace(r'-[0-9a-f]{8}$', '', regex=True)

fig, axes = plt.subplots(1, 2, figsize=(18, 8), gridspec_kw={'width_ratios': [1.25, 1]})

score_long = plot_df.melt(
    id_vars=['track_id', 'short_id'],
    value_vars=['beat_F-measure', 'downbeat_F-measure'],
    var_name='metric',
    value_name='F-measure',
)
sns.barplot(
    data=score_long,
    y='short_id',
    x='F-measure',
    hue='metric',
    palette={'beat_F-measure': '#2878b5', 'downbeat_F-measure': '#c43c39'},
    ax=axes[0],
)
axes[0].set_xlim(0, 1)
axes[0].set_ylabel('')
axes[0].set_xlabel('F-measure')
axes[0].set_title('Lowest beat F-measure tracks')
axes[0].legend(title='', loc='lower right')

count_long = plot_df.melt(
    id_vars=['track_id', 'short_id'],
    value_vars=['beat_count_ratio', 'downbeat_count_ratio'],
    var_name='event type',
    value_name='predicted / reference count',
)
sns.scatterplot(
    data=count_long,
    x='predicted / reference count',
    y='short_id',
    hue='event type',
    style='event type',
    s=110,
    palette={'beat_count_ratio': '#2878b5', 'downbeat_count_ratio': '#c43c39'},
    ax=axes[1],
)
axes[1].axvline(1.0, color='black', lw=1, ls='--')
axes[1].set_xlim(0, max(3, count_long['predicted / reference count'].quantile(0.95) * 1.1))
axes[1].set_ylabel('')
axes[1].set_title('Event count sanity check')
axes[1].legend(title='', loc='lower right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Beat overlays
#
# Each row below uses the cached prediction file and reference beat CSV. The top panel is a
# full-track event overlay; the bottom panel zooms into the 45 s region with the largest
# beat-count disagreement, using 70 ms matching tolerance.

# %%
def load_reference_events(track_id):
    beat_csv = JTD_ROOT / track_id / 'beats.csv'
    if not beat_csv.exists():
        return None, None
    ann = pd.read_csv(beat_csv)
    ref_beats = ann['beats'].dropna().to_numpy(dtype=float)
    ref_downbeats = ann.loc[ann['metre_auto'].eq(1), 'beats'].dropna().to_numpy(dtype=float)
    return ref_beats, ref_downbeats


def load_predicted_events(track_id):
    pred_path = PREDS_DIR / f'{track_id}.npz'
    if not pred_path.exists():
        return None, None
    pred = np.load(pred_path)
    return pred['beats'], pred['downbeats']


def unmatched_count(reference, predicted, start, end, tolerance=0.07):
    ref = reference[(reference >= start) & (reference < end)]
    pred = predicted[(predicted >= start) & (predicted < end)]
    if len(ref) == 0 and len(pred) == 0:
        return 0
    if len(ref) == 0 or len(pred) == 0:
        return len(ref) + len(pred)
    matched_ref = np.zeros(len(ref), dtype=bool)
    matched_pred = np.zeros(len(pred), dtype=bool)
    for i, r in enumerate(ref):
        j = np.argmin(np.abs(pred - r))
        if abs(pred[j] - r) <= tolerance and not matched_pred[j]:
            matched_ref[i] = True
            matched_pred[j] = True
    return int((~matched_ref).sum() + (~matched_pred).sum())


def worst_error_window(ref_beats, pred_beats, duration=45.0, step=10.0):
    if ref_beats is None or pred_beats is None or len(ref_beats) == 0 or len(pred_beats) == 0:
        return 0.0, duration
    end_time = max(ref_beats.max(), pred_beats.max())
    if end_time <= duration:
        return 0.0, end_time
    starts = np.arange(0, max(step, end_time - duration), step)
    scores = [unmatched_count(ref_beats, pred_beats, s, s + duration) for s in starts]
    start = float(starts[int(np.argmax(scores))])
    return start, start + duration


def draw_event_overlay(ax, ref_beats, ref_downbeats, pred_beats, pred_downbeats, title, start=None, end=None):
    lanes = [
        ('Reference beats', ref_beats, '#1f77b4', 0.35, 0.9),
        ('Predicted beats', pred_beats, '#ff7f0e', 0.35, 0.9),
        ('Reference downbeats', ref_downbeats, '#0b3d91', 0.75, 1.6),
        ('Predicted downbeats', pred_downbeats, '#b22222', 0.75, 1.6),
    ]
    y_positions = np.arange(len(lanes), 0, -1)
    for y, (label, values, color, alpha, lw) in zip(y_positions, lanes):
        values = np.asarray([] if values is None else values, dtype=float)
        if start is not None and end is not None:
            values = values[(values >= start) & (values <= end)]
        ax.eventplot(values, lineoffsets=y, linelengths=0.72, colors=color, alpha=alpha, linewidths=lw)
    ax.set_yticks(y_positions)
    ax.set_yticklabels([lane[0] for lane in lanes], fontsize=9)
    ax.set_xlabel('Time (s)')
    ax.set_title(title, fontsize=12, loc='left')
    ax.grid(axis='x', alpha=0.25)
    if start is not None and end is not None:
        ax.set_xlim(start, end)
    else:
        all_values = [v for _, values, *_ in lanes for v in np.asarray([] if values is None else values, dtype=float)]
        if all_values:
            ax.set_xlim(0, max(all_values))


def plot_worst_track_overlay(track_id):
    ref_beats, ref_downbeats = load_reference_events(track_id)
    pred_beats, pred_downbeats = load_predicted_events(track_id)
    if ref_beats is None or pred_beats is None:
        print(f'Skipping {track_id}: missing reference or prediction file.')
        return

    row = df.loc[df['track_id'].eq(track_id)].iloc[0]
    fig, axes = plt.subplots(2, 1, figsize=(16, 4.8), sharey=False)
    title = (
        f"{track_id} | beat F={row['beat_F-measure']:.3f}, "
        f"downbeat F={row['downbeat_F-measure']:.3f}, "
        f"beat count {int(row['n_pred_beats'])}/{int(row['n_gt_beats'])}"
    )
    draw_event_overlay(axes[0], ref_beats, ref_downbeats, pred_beats, pred_downbeats, title)
    start, end = worst_error_window(ref_beats, pred_beats)
    draw_event_overlay(
        axes[1], ref_beats, ref_downbeats, pred_beats, pred_downbeats,
        f'Zoomed mismatch window: {start:.0f}-{end:.0f} s',
        start=start, end=end,
    )
    plt.tight_layout()
    plt.show()


for track_id in worst_tracks['track_id'].head(6):
    plot_worst_track_overlay(track_id)

# %% [markdown]
# ### Waveforms and listening
#
# The downloaded WAVs are loaded from `audio/worst_finetuned_test`. Each waveform
# shows reference beats/downbeats above the signal and predicted beats/downbeats below it.
# The audio controls underneath reference the local WAV files directly, so the notebook
# stays small while still letting you listen in place.

# %%
from IPython.display import HTML
from html import escape
from scipy.io import wavfile

AUDIO_DIR = Path('audio/worst_finetuned_test')


def local_audio_path(track_id):
    candidates = [
        AUDIO_DIR / f'{track_id}.wav',
        Path('../jazz-trio-database-v02') / track_id / f'{track_id}.wav',
        Path('../test_audio') / f'{track_id}.wav',
        Path('..') / 'test_audio' / f'{track_id}.wav',
    ]
    for candidate in candidates:
        if candidate.exists():
            return candidate
    return None


def plot_waveform_with_markers(track_id, seconds=None):
    audio_path = local_audio_path(track_id)
    if audio_path is None:
        print(f'No local WAV found for {track_id}.')
        return
    ref_beats, ref_downbeats = load_reference_events(track_id)
    pred_beats, pred_downbeats = load_predicted_events(track_id)
    sr, y = wavfile.read(audio_path)
    y = np.asarray(y, dtype=float)
    if y.ndim > 1:
        y = y.mean(axis=1)
    peak = np.max(np.abs(y))
    if peak > 0:
        y = y / peak
    target_sr = 22050
    if sr > target_sr:
        step = max(1, int(round(sr / target_sr)))
        y = y[::step]
        sr = sr / step
    duration = len(y) / sr
    end = min(duration, seconds) if seconds is not None else duration
    y_plot = y[: int(end * sr)]
    times = np.arange(len(y_plot)) / sr

    row = df.loc[df['track_id'].eq(track_id)].iloc[0]
    fig, ax = plt.subplots(figsize=(16, 3.8))
    ax.plot(times, y_plot, color='#5b6770', lw=0.45, alpha=0.75)
    ymin, ymax = np.percentile(y_plot, [1, 99])
    pad = max(0.05, (ymax - ymin) * 0.35)
    ymin, ymax = ymin - pad, ymax + pad

    marker_sets = [
        ('Reference beats', ref_beats, '#1f77b4', 0.26, 0.7, 0.58),
        ('Reference downbeats', ref_downbeats, '#0b3d91', 0.72, 1.35, 0.98),
        ('Predicted beats', pred_beats, '#ff7f0e', 0.26, 0.7, -0.58),
        ('Predicted downbeats', pred_downbeats, '#b22222', 0.72, 1.35, -0.98),
    ]
    handles = []
    for label, values, color, alpha, lw, height_frac in marker_sets:
        values = np.asarray([] if values is None else values, dtype=float)
        values = values[(values >= 0) & (values <= end)]
        if height_frac > 0:
            y0, y1 = ymax * 0.12, ymax * height_frac
        else:
            y0, y1 = ymin * 0.12, ymin * abs(height_frac)
        handle = ax.vlines(values, y0, y1, color=color, alpha=alpha, lw=lw, label=label)
        handles.append(handle)

    title = (
        f"{track_id} | beat F={row['beat_F-measure']:.3f}, "
        f"downbeat F={row['downbeat_F-measure']:.3f}"
    )
    ax.set_title(title, loc='left', fontsize=12)
    ax.set_xlim(0, end)
    ax.set_ylim(ymin, ymax)
    ax.set_xlabel('Time (s)')
    ax.set_ylabel('Amplitude')
    ax.legend(loc='upper right', ncols=2, fontsize=8, frameon=True)
    ax.grid(axis='x', alpha=0.18)
    plt.tight_layout()
    plt.show()


def audio_player(track_id):
    audio_path = local_audio_path(track_id)
    if audio_path is None:
        return HTML(f'<p><strong>{escape(track_id)}</strong>: no local WAV found.</p>')
    src = escape(str(audio_path))
    label = escape(track_id)
    return HTML(
        f'<div style="margin: 0.5rem 0 1rem 0;">'
        f'<div style="font-weight:600; margin-bottom:0.25rem;">{label}</div>'
        f'<audio controls preload="none" style="width: 100%;" src="{src}"></audio>'
        f'</div>'
    )


for track_id in worst_tracks['track_id']:
    plot_waveform_with_markers(track_id)
    display(audio_player(track_id))
# Out:
# <div style="margin: 0.5rem 0 1rem 0;"><div style="font-weight:600; margin-bottom:0.25rem;">tynerm-darnthatdream-sharpeascotta-1989-6cc187a8</div><audio controls preload="none" style="width: 100%;" src="audio/worst_finetuned_test/tynerm-darnthatdream-sharpeascotta-1989-6cc187a8.wav"></audio></div>
# <div style="margin: 0.5rem 0 1rem 0;"><div style="font-weight:600; margin-bottom:0.25rem;">jarrettk-ithoughtaboutyou-peacockgdejohnettej-1993-340a16bd</div><audio controls preload="none" style="width: 100%;" src="audio/worst_finetuned_test/jarrettk-ithoughtaboutyou-peacockgdejohnettej-1993-340a16bd.wav"></audio></div>
# <div style="margin: 0.5rem 0 1rem 0;"><div style="font-weight:600; margin-bottom:0.25rem;">brownr-myheartstoodstill-smithpbellsonl-1978-d3d8fdc4</div><audio controls preload="none" style="width: 100%;" src="audio/worst_finetuned_test/brownr-myheartstoodstill-smithpbellsonl-1978-d3d8fdc4.wav"></audio></div>
# <div style="margin: 0.5rem 0 1rem 0;"><div style="font-weight:600; margin-bottom:0.25rem;">monkt-aprilinparis-rameygblakeya-1949-c50b1c36</div><audio controls preload="none" style="width: 100%;" src="audio/worst_finetuned_test/monkt-aprilinparis-rameygblakeya-1949-c50b1c36.wav"></audio></div>
# <div style="margin: 0.5rem 0 1rem 0;"><div style="font-weight:600; margin-bottom:0.25rem;">bleyp-syndrome-swallowslap-1963-e13458a9</div><audio controls preload="none" style="width: 100%;" src="audio/worst_finetuned_test/bleyp-syndrome-swallowslap-1963-e13458a9.wav"></audio></div>
# <div style="margin: 0.5rem 0 1rem 0;"><div style="font-weight:600; margin-bottom:0.25rem;">jamala-yougotomyhead-crosbyifournierv-1960-5a0737d3</div><audio controls preload="none" style="width: 100%;" src="audio/worst_finetuned_test/jamala-yougotomyhead-crosbyifournierv-1960-5a0737d3.wav"></audio></div>
# <div style="margin: 0.5rem 0 1rem 0;"><div style="font-weight:600; margin-bottom:0.25rem;">coreac-sophisticatedlady-patituccijweckld-1989-85cb4d64</div><audio controls preload="none" style="width: 100%;" src="audio/worst_finetuned_test/coreac-sophisticatedlady-patituccijweckld-1989-85cb4d64.wav"></audio></div>
# <div style="margin: 0.5rem 0 1rem 0;"><div style="font-weight:600; margin-bottom:0.25rem;">barronk-thereisnogreaterlove-williamsbrileyb-1984-90d41f7e</div><audio controls preload="none" style="width: 100%;" src="audio/worst_finetuned_test/barronk-thereisnogreaterlove-williamsbrileyb-1984-90d41f7e.wav"></audio></div>
# <div style="margin: 0.5rem 0 1rem 0;"><div style="font-weight:600; margin-bottom:0.25rem;">jarrettk-lisbonstomp-hadencmotianp-1968-8994c848</div><audio controls preload="none" style="width: 100%;" src="audio/worst_finetuned_test/jarrettk-lisbonstomp-hadencmotianp-1968-8994c848.wav"></audio></div>
# <div style="margin: 0.5rem 0 1rem 0;"><div style="font-weight:600; margin-bottom:0.25rem;">jamala-angeleyes-crosbyifournierv-1961-69a58683</div><audio controls preload="none" style="width: 100%;" src="audio/worst_finetuned_test/jamala-angeleyes-crosbyifournierv-1961-69a58683.wav"></audio></div>
# <div style="margin: 0.5rem 0 1rem 0;"><div style="font-weight:600; margin-bottom:0.25rem;">kellyw-dontchahearmecallin-mcclurercobbj-1966-c450ccdb</div><audio controls preload="none" style="width: 100%;" src="audio/worst_finetuned_test/kellyw-dontchahearmecallin-mcclurercobbj-1966-c450ccdb.wav"></audio></div>
# <div style="margin: 0.5rem 0 1rem 0;"><div style="font-weight:600; margin-bottom:0.25rem;">evansb-waltzfordebby-gomezemorellm-1972-3cb853ec</div><audio controls preload="none" style="width: 100%;" src="audio/worst_finetuned_test/evansb-waltzfordebby-gomezemorellm-1972-3cb853ec.wav"></audio></div>
