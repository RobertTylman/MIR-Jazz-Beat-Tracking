# %%
from support_function import plot_beats
from run_beat_this import run_beat_this

# %%
checkpoint_path = "./beat_this/checkpoint/final0.ckpt"  # Update this path to your checkpoint
audio_path = "./test_audio/test_1.mp3"
beat, downbeat = run_beat_this(checkpoint_path=checkpoint_path, audio_path=audio_path)

plot_beats(audio_path, beat, downbeat)
